# %%
import matplotlib.pyplot as plt

# Data from the results
qubit_no = [4, 8, 12, 16]

# NAB Scores for each method
nab_scores = {
    "QEAD": [0.853, 0.755, 0.738, 0.574],
    "QSA": [0.0, 0.0, 0.0, 0.0],
    "Self Attention DNN": [0.395, 0.763, 0.705, 0.452],
    "CNN DNN": [0.802, 0.611, 0.681, 0.811],
}

# MCC for each method
mcc_scores = {
    "QEAD": [0.778, 0.686, 0.661, 0.568],
    "QSA": [0.0, 0.0, 0.0, 0.0],
    "Self Attention DNN": [0.582, 0.735, 0.792, 0.624],
    "CNN DNN": [0.779, 0.743, 0.791, 0.853],
}

# Accuracy for each method
accuracy_scores = {
    "QEAD": [0.939, 0.915, 0.914, 0.879],
    "QSA": [0.864, 0.867, 0.880, 0.841],
    "Self Attention DNN": [0.915, 0.935, 0.959, 0.910],
    "CNN DNN": [0.946, 0.945, 0.959, 0.962],
}

# Time for each method (in seconds)
time_scores = {
    "QEAD": [23.46909, 65.39565, 94.77069, 865.42387],
    "QSA": [62.61463, 128.25342, 2367.16550, 41499.56750],
    "Self Attention DNN": [0.69810, 1.83218, 0.69908, 1.01830],
    "CNN DNN": [0.61562, 2.31670, 0.59276, 1.08306],
}

# Plotting the results

fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot NAB Scores
for method, scores in nab_scores.items():
    axs[0, 0].plot(qubit_no, scores, label=method, marker='o')
axs[0, 0].set_title('NAB Score vs Qubit No')
axs[0, 0].set_xlabel('Qubit No')
axs[0, 0].set_ylabel('NAB Score')
axs[0, 0].legend()

# Plot MCC Scores
for method, scores in mcc_scores.items():
    axs[0, 1].plot(qubit_no, scores, label=method, marker='o')
axs[0, 1].set_title('MCC vs Qubit No')
axs[0, 1].set_xlabel('Qubit No')
axs[0, 1].set_ylabel('MCC')
axs[0, 1].legend()

# Plot Accuracy Scores
for method, scores in accuracy_scores.items():
    axs[1, 0].plot(qubit_no, scores, label=method, marker='o')
axs[1, 0].set_title('Accuracy vs Qubit No')
axs[1, 0].set_xlabel('Qubit No')
axs[1, 0].set_ylabel('Accuracy')
axs[1, 0].legend()

# Plot Time Scores
for method, scores in time_scores.items():
    axs[1, 1].plot(qubit_no, scores, label=method, marker='o')
axs[1, 1].set_title('Time vs Qubit No')
axs[1, 1].set_xlabel('Qubit No')
axs[1, 1].set_ylabel('Time (s)')
axs[1, 1].legend()

plt.tight_layout()
plt.show()
